-- %%
select * from datasets.kbf1984.brz_pr_class;
select * from datasets.kbf1984.brz_pr_duration;
select * from datasets.kbf1984.brz_pr_footnote;
select * from datasets.kbf1984.brz_pr_measure;
select * from datasets.kbf1984.brz_pr_period;
select * from datasets.kbf1984.brz_pr_seasonal;
select * from datasets.kbf1984.brz_pr_sector;
select * from datasets.kbf1984.brz_pr_series;
select * from datasets.kbf1984.brz_pr_data_0_current;
select * from datasets.kbf1984.brz_pr_data_1_alldata;

select * from datasets.kbf1984.slv_pr_class;
select * from datasets.kbf1984.slv_pr_duration;
select * from datasets.kbf1984.slv_pr_footnote;
select * from datasets.kbf1984.slv_pr_measure;
select * from datasets.kbf1984.slv_pr_period;
select * from datasets.kbf1984.slv_pr_seasonal;
select * from datasets.kbf1984.slv_pr_sector;
select * from datasets.kbf1984.slv_pr_series;
select * from datasets.kbf1984.slv_pr_productivity;

select * from datasets.kbf1984.gold_dim_class;
select * from datasets.kbf1984.gold_dim_duration;
select * from datasets.kbf1984.gold_dim_footnote;
select * from datasets.kbf1984.gold_dim_measure;
select * from datasets.kbf1984.gold_dim_period;
select * from datasets.kbf1984.gold_dim_seasonal;
select * from datasets.kbf1984.gold_dim_sector;
select * from datasets.kbf1984.gold_fact_productivity;

select * from datasets.kbf1984.brz_population_data;

select * from datasets.kbf1984.slv_population_nation;
select * from datasets.kbf1984.slv_population;

select * from datasets.kbf1984.gold_dim_nation;
select * from datasets.kbf1984.gold_fact_population;
